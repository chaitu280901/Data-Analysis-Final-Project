# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
sns.set(style="white")
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
import pickle as pkl

# %%
with open("cleaned_df.pkl","rb") as f:
    cleaned_autos = pkl.load(f)  ## Loading data from cleaned_df.pkl

# %%
df=cleaned_autos.copy()

# %%
df
# Out:
#                                          name   seller        model  \
# 0                                  Golf 3 1.6  private         golf
# 1                        A5 Sportback 2.7 Tdi  private        Other
# 2              Jeep Grand Cherokee "Overland"  private        grand
# 3                          GOLF 4 1 4  3TÜRER  private         golf
# 4              Skoda Fabia 1.4 TDI PD Classic  private        fabia
# ...                                       ...      ...          ...
# 371522                        Mitsubishi Cold  private         colt
# 371523             Suche t4   vito ab 6 sitze  private        Other
# 371524  Smart smart leistungssteigerung 100ps  private       fortwo
# 371525     Volkswagen Multivan T4 TDI 7DC UY2  private  transporter
# 371526                 VW Golf Kombi 1 9l TDI  private         golf
#
#                  brand offerType  price   abtest  vehicleType      gearbox  \
# 0           volkswagen     Offer    480     test        Other       Manual
# 1                 audi     Offer  18300     test        coupe       Manual
# 2                 jeep     Offer   9800     test          suv    Automatic
# 3           volkswagen     Offer   1500     test  compact car       Manual
# 4                skoda     Offer   3600     test  compact car       Manual
# ...                ...       ...    ...      ...          ...          ...
# 371522      mitsubishi     Offer      0  control        Other       Manual
# 371523  sonstige_autos     Offer   2200     test        Other  Unspecified
# 371524           smart     Offer   1199     test  convertible    Automatic
# 371525      volkswagen     Offer   9200     test          bus       Manual
# 371526      volkswagen     Offer   3400     test        kombi       Manual
#
#         powerPS fuelType  kilometer notRepairedDamage  yearOfRegistration  \
# 0             0   petrol     150000             Other                1993
# 1           190   diesel     125000               Yes                2011
# 2           163   diesel     125000             Other                2004
# 3            75   petrol     150000                No                2001
# 4            69   diesel      90000                No                2008
# ...         ...      ...        ...               ...                 ...
# 371522        0   petrol     150000               Yes                2005
# 371523        0    Other      20000             Other                2005
# 371524      101   petrol     125000                No                2000
# 371525      102   diesel     150000                No                1996
# 371526      100   diesel     150000             Other                2002
#
#        monthOfRegistration  postalCode         dateCrawled dateCreated  \
# 0                  January       70435 2016-03-24 11:52:17  2016-03-24
# 1                      May       66954 2016-03-24 10:58:45  2016-03-24
# 2                   August       90480 2016-03-14 12:52:21  2016-03-14
# 3                     June       91074 2016-03-17 16:54:04  2016-03-17
# 4                     July       60437 2016-03-31 17:25:20  2016-03-31
# ...                    ...         ...                 ...         ...
# 371522                July        2694 2016-03-21 09:50:58  2016-03-21
# 371523             January       39576 2016-03-14 17:48:27  2016-03-14
# 371524               March       26135 2016-03-05 19:56:21  2016-03-05
# 371525               March       87439 2016-03-19 18:57:12  2016-03-19
# 371526                June       40764 2016-03-20 19:41:08  2016-03-20
#
#                   lastSeen
# 0      2016-04-07 03:16:57
# 1      2016-04-07 01:46:50
# 2      2016-04-05 12:47:46
# 3      2016-03-17 17:40:17
# 4      2016-04-06 10:17:21
# ...                    ...
# 371522 2016-03-21 10:42:49
# 371523 2016-04-06 00:46:52
# 371524 2016-03-11 18:17:12
# 371525 2016-04-07 07:15:26
# 371526 2016-03-24 12:45:21
#
# [326472 rows x 19 columns]

# %% [markdown]
# ## Can you tell me No of Vehicles by Brand Available on ebay for sale with the help of visualization

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='brand', data=df)
plt.title("Sales By Brand")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## What is the Average price for vehicles based on the type of vehicle as well as on the type of gearbox.Explain me with both numerical and visualization analysis?

# %%
fig, ax = plt.subplots(figsize=(8,5))
colors = ["#00e600", "#ff8c1a","#a180cc"]
sns.barplot(x="vehicleType", y="price",hue="gearbox", palette=colors, data=df)
ax.set_title("Average price of vehicles by vehicle type and gearbox type",fontdict= {'size':12})
ax.xaxis.set_label_text("Type Of Vehicle",fontdict= {'size':12})
ax.yaxis.set_label_text("Average Price",fontdict= {'size':12})
plt.show()

# %% [markdown]
# ## What is the marginal probability of private seller?

# %%
margin=(len(df[df['seller']=='private']))/(len(df))
print(f"{margin:.7f}")
# Out:
# 0.9999908
